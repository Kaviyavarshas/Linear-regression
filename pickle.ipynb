# %%
import pickle as pk

# %%
pk.load("Batch_13_model.pkl")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 pk.load("Batch_13_model.pkl")
#
# TypeError: file must have 'read' and 'readline' attributes
